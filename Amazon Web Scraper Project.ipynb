# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
#Connect to Website

URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'


headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers = headers)

soup1 = BeautifulSoup(page.content,"html.parser")

soup2 = BeautifulSoup(soup1.prettify(),"html.parser")



title = soup2.find("span", attrs={'class':'a-size-large product-title-word-break'}).text.strip()

price = soup2.find("span", attrs={'class':'a-offscreen'}).text.strip()[1:]

print(title)
print(price)
# Out:
# Funny Got Data MIS Data Systems Business Analyst T-Shirt
# 16.99

# %%
today = datetime.date.today()
print(today)
# Out:
# 2023-02-20

# %%
import csv

header = ["Title","Price","Date"]
data = [title,price,today]


with open('AmazonWebScraperDataset.csv','w',newline = '',encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\cwy96\AmazonWebScraperDataset.csv')
df
# Out:
#                                                Title  Price        Date
# 0  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 1  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 2  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 3  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 4  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 5  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 6  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 7  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 8  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20

# %%
# Now we are appending data to the csv


with open('AmazonWebScraperDataset.csv','a+',newline = '',encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    
    URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers = headers)

    soup1 = BeautifulSoup(page.content,"html.parser")

    soup2 = BeautifulSoup(soup1.prettify(),"html.parser")



    title = soup2.find("span", attrs={'class':'a-size-large product-title-word-break'}).text.strip()

    price = soup2.find("span", attrs={'class':'a-offscreen'}).text.strip()[1:]
    
    import datetime
    
    today = datetime.date.today()
    
    import csv

    data = [title,price,today]


    with open('AmazonWebScraperDataset.csv','a+',newline = '',encoding = 'UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
# update the price per day 
while True:
    check_price()
    time.sleep(86400)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22496\3958124450.py in <module>
#       1 # update the price per day
#       2 while True:
# ----> 3     check_price()
#       4     time.sleep(86400)
#
# ~\AppData\Local\Temp\ipykernel_22496\3583341072.py in check_price()
#       5     headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
#       6
# ----> 7     page = requests.get(URL, headers = headers)
#       8
#       9     soup1 = BeautifulSoup(page.content,"html.parser")
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     743
#     744         if not stream:
# --> 745             r.content
#     746
#     747         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     621         """
#     622         if self.chunked and self.supports_chunked_reads():
# --> 623             for line in self.read_chunked(amt, decode_content=decode_content):
#     624                 yield line
#     625         else:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     813
#     814             while True:
# --> 815                 self._update_chunk_length()
#     816                 if self.chunk_left == 0:
#     817                     break
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     743         if self.chunk_left is not None:
#     744             return
# --> 745         line = self._fp.fp.readline()
#     746         line = line.split(b";", 1)[0]
#     747         try:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\cwy96\AmazonWebScraperDataset.csv')
df
# Out:
#                                                 Title  Price        Date
# 0   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 1   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 2   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 3   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 4   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 5   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 6   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 7   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 8   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 9   Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 10  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 11  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 12  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 13  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 14  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 15  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 16  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 17  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 18  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 19  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
# 20  Funny Got Data MIS Data Systems Business Analy...  16.99  2023-02-20
